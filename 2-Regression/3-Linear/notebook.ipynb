# %% [markdown]
# ## Pumpkin Pricing
#
# Load up required libraries and dataset. Convert the data to a dataframe containing a subset of the data:
#
# - Only get pumpkins priced by the bushel
# - Convert the date to a month
# - Calculate the price to be an average of high and low prices
# - Convert the price to reflect the pricing by bushel quantity

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

pumpkins = pd.read_csv('../data/US-pumpkins.csv')

pumpkins.head()
# Out:
#    City Name Type       Package      Variety Sub Variety  Grade     Date  \
# 0  BALTIMORE  NaN  24 inch bins          NaN         NaN    NaN  4/29/17
# 1  BALTIMORE  NaN  24 inch bins          NaN         NaN    NaN   5/6/17
# 2  BALTIMORE  NaN  24 inch bins  HOWDEN TYPE         NaN    NaN  9/24/16
# 3  BALTIMORE  NaN  24 inch bins  HOWDEN TYPE         NaN    NaN  9/24/16
# 4  BALTIMORE  NaN  24 inch bins  HOWDEN TYPE         NaN    NaN  11/5/16
#
#    Low Price  High Price  Mostly Low  ...  Unit of Sale Quality Condition  \
# 0      270.0       280.0       270.0  ...           NaN     NaN       NaN
# 1      270.0       280.0       270.0  ...           NaN     NaN       NaN
# 2      160.0       160.0       160.0  ...           NaN     NaN       NaN
# 3      160.0       160.0       160.0  ...           NaN     NaN       NaN
# 4       90.0       100.0        90.0  ...           NaN     NaN       NaN
#
#   Appearance Storage  Crop Repack  Trans Mode  Unnamed: 24  Unnamed: 25
# 0        NaN     NaN   NaN      E         NaN          NaN          NaN
# 1        NaN     NaN   NaN      E         NaN          NaN          NaN
# 2        NaN     NaN   NaN      N         NaN          NaN          NaN
# 3        NaN     NaN   NaN      N         NaN          NaN          NaN
# 4        NaN     NaN   NaN      N         NaN          NaN          NaN
#
# [5 rows x 26 columns]

# %%
pumpkins = pumpkins[pumpkins['Package'].str.contains('bushel', case=True, regex=True)]

new_columns = ['Package', 'Variety', 'City Name', 'Month', 'Low Price', 'High Price', 'Date', 'City Num', 'Variety Num']


pumpkins = pumpkins.drop([c for c in pumpkins.columns if c not in new_columns], axis=1)

price = (pumpkins['Low Price'] + pumpkins['High Price']) / 2

month = pd.DatetimeIndex(pumpkins['Date']).month


new_pumpkins = pd.DataFrame({'Month': month, 'Variety': pumpkins['Variety'], 'City': pumpkins['City Name'], 'Package': pumpkins['Package'], 'Low Price': pumpkins['Low Price'],'High Price': pumpkins['High Price'], 'Price': price})

new_pumpkins.loc[new_pumpkins['Package'].str.contains('1 1/9'), 'Price'] = price/1.1

new_pumpkins.loc[new_pumpkins['Package'].str.contains('1/2'), 'Price'] = price*2

new_pumpkins.head()
# Out:
#     Month   Variety       City               Package  Low Price  High Price  \
# 70      9  PIE TYPE  BALTIMORE  1 1/9 bushel cartons       15.0        15.0
# 71      9  PIE TYPE  BALTIMORE  1 1/9 bushel cartons       18.0        18.0
# 72     10  PIE TYPE  BALTIMORE  1 1/9 bushel cartons       18.0        18.0
# 73     10  PIE TYPE  BALTIMORE  1 1/9 bushel cartons       17.0        17.0
# 74     10  PIE TYPE  BALTIMORE  1 1/9 bushel cartons       15.0        15.0
#
#         Price
# 70  13.636364
# 71  16.363636
# 72  16.363636
# 73  15.454545
# 74  13.636364

# %% [markdown]
# A basic scatterplot reminds us that we only have month data from August through December. We probably need more data to be able to draw conclusions in a linear fashion.

# %%
import matplotlib.pyplot as plt
plt.scatter('City','Price',data=new_pumpkins)

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split

new_pumpkins.iloc[:, 0:-1] = new_pumpkins.iloc[:, 0:-1].apply(LabelEncoder().fit_transform)
new_pumpkins.dropna(inplace=True)
new_columns = ['Package', 'Price']
lin_pumpkins = new_pumpkins.drop([c for c in new_pumpkins.columns if c not in new_columns], axis='columns')
X = lin_pumpkins.values[:, :1]
y = lin_pumpkins.values[:, 1:2]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
lin_reg = LinearRegression()
lin_reg.fit(X_train,y_train)

pred = lin_reg.predict(X_test)

accuracy_score = lin_reg.score(X_train,y_train)
print('Model Accuracy: ', accuracy_score)
plt.scatter(X_test, y_test,  color='black')
plt.plot(X_test, pred, color='blue', linewidth=3)

plt.xlabel('Package')
plt.ylabel('Price')

plt.show()
# Out:
# Model Accuracy:  0.3315342327998989

# %% [markdown]
# # polynomial regression

# %%
new_columns = ['Variety', 'Package', 'City', 'Month', 'Price']
poly_pumpkins = new_pumpkins.drop([c for c in new_pumpkins.columns if c not in new_columns], axis='columns')
X=poly_pumpkins.iloc[:,3:4].values
y=poly_pumpkins.iloc[:,4:5].values
corr = poly_pumpkins.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_348b0_row0_col0, #T_348b0_row1_col1, #T_348b0_row2_col2, #T_348b0_row3_col3, #T_348b0_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_348b0_row0_col1 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_348b0_row0_col2 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_348b0_row0_col3 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_348b0_row0_col4 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_348b0_row1_col0 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_348b0_row1_col2, #T_348b0_row1_col3, #T_348b0_row1_col4, #T_348b0_row2_col0, #T_348b0_row4_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_348b0_row2_col1 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_348b0_row2_col3 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_348b0_row2_col4 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_348b0_row3_col0 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_348b0_row3_col1 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_348b0_row3_col2 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_348b0_row3_col4 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_348b0_row4_col0 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_348b0_row4_col2 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_348b0_row4_col3 {
#   background-color: #f39778;
#   color: #000000;
# }
# </style>
# <table id="T_348b0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_348b0_level0_col0" class="col_heading level0 col0" >Month</th>
#       <th id="T_348b0_level0_col1" class="col_heading level0 col1" >Variety</th>
#       <th id="T_348b0_level0_col2" class="col_heading level0 col2" >City</th>
#       <th id="T_348b0_level0_col3" class="col_heading level0 col3" >Package</th>
#       <th id="T_348b0_level0_col4" class="col_heading level0 col4" >Price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_348b0_level0_row0" class="row_heading level0 row0" >Month</th>
#       <td id="T_348b0_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_348b0_row0_col1" class="data row0 col1" >0.171330</td>
#       <td id="T_348b0_row0_col2" class="data row0 col2" >-0.188728</td>
#       <td id="T_348b0_row0_col3" class="data row0 col3" >-0.144847</td>
#       <td id="T_348b0_row0_col4" class="data row0 col4" >-0.148783</td>
#     </tr>
#     <tr>
#       <th id="T_348b0_level0_row1" class="row_heading level0 row1" >Variety</th>
#       <td id="T_348b0_row1_col0" class="data row1 col0" >0.171330</td>
#       <td id="T_348b0_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_348b0_row1_col2" class="data row1 col2" >-0.248441</td>
#       <td id="T_348b0_row1_col3" class="data row1 col3" >-0.614855</td>
#       <td id="T_348b0_row1_col4" class="data row1 col4" >-0.863479</td>
#     </tr>
#     <tr>
#       <th id="T_348b0_level0_row2" class="row_heading level0 row2" >City</th>
#       <td id="T_348b0_row2_col0" class="data row2 col0" >-0.188728</td>
#       <td id="T_348b0_row2_col1" class="data row2 col1" >-0.248441</td>
#       <td id="T_348b0_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_348b0_row2_col3" class="data row2 col3" >0.301604</td>
#       <td id="T_348b0_row2_col4" class="data row2 col4" >0.323640</td>
#     </tr>
#     <tr>
#       <th id="T_348b0_level0_row3" class="row_heading level0 row3" >Package</th>
#       <td id="T_348b0_row3_col0" class="data row3 col0" >-0.144847</td>
#       <td id="T_348b0_row3_col1" class="data row3 col1" >-0.614855</td>
#       <td id="T_348b0_row3_col2" class="data row3 col2" >0.301604</td>
#       <td id="T_348b0_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_348b0_row3_col4" class="data row3 col4" >0.606171</td>
#     </tr>
#     <tr>
#       <th id="T_348b0_level0_row4" class="row_heading level0 row4" >Price</th>
#       <td id="T_348b0_row4_col0" class="data row4 col0" >-0.148783</td>
#       <td id="T_348b0_row4_col1" class="data row4 col1" >-0.863479</td>
#       <td id="T_348b0_row4_col2" class="data row4 col2" >0.323640</td>
#       <td id="T_348b0_row4_col3" class="data row4 col3" >0.606171</td>
#       <td id="T_348b0_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

pipeline = make_pipeline(PolynomialFeatures(4), LinearRegression())
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
pipeline.fit(np.array(X_train), y_train)
y_pred=pipeline.predict(X_test)

df = pd.DataFrame({'x': X_test[:,0], 'y': y_pred[:,0]})
df.sort_values(by='x',inplace = True)
points = pd.DataFrame(df).to_numpy()

plt.plot(points[:, 0], points[:, 1],color="blue", linewidth=3)
plt.xlabel('Package')
plt.ylabel('Price')
plt.scatter(X,y, color="black")
plt.show()

# %%
accuracy_score = pipeline.score(X_train,y_train)
print('Model Accuracy: ', accuracy_score)
# Out:
# Model Accuracy:  0.8537946517073784

# %%
pipeline.predict( np.array([ [2.75] ]) )
# Out:
# array([[46.34509342]])

# %% [markdown]
# # Assignment

# %%
from sklearn import datasets, linear_model, model_selection

diabetes_frame = datasets.load_diabetes(as_frame=True).frame
diabetes_frame
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017282 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081414  0.083740  0.027809  0.173816
#
#            s4        s5        s6  target
# 0   -0.002592  0.019908 -0.017646   151.0
# 1   -0.039493 -0.068330 -0.092204    75.0
# 2   -0.002592  0.002864 -0.025930   141.0
# 3    0.034309  0.022692 -0.009362   206.0
# 4   -0.002592 -0.031991 -0.046641   135.0
# ..        ...       ...       ...     ...
# 437 -0.002592  0.031193  0.007207   178.0
# 438  0.034309 -0.018118  0.044485   104.0
# 439 -0.011080 -0.046879  0.015491   132.0
# 440  0.026560  0.044528 -0.025930   220.0
# 441 -0.039493 -0.004220  0.003064    57.0
#
# [442 rows x 11 columns]

# %%
corr = diabetes_frame.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_40442_row0_col0, #T_40442_row1_col1, #T_40442_row2_col2, #T_40442_row3_col3, #T_40442_row4_col4, #T_40442_row5_col5, #T_40442_row6_col6, #T_40442_row7_col7, #T_40442_row8_col8, #T_40442_row9_col9, #T_40442_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_40442_row0_col1 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_40442_row0_col2 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_40442_row0_col3, #T_40442_row4_col10 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_40442_row0_col4, #T_40442_row1_col0 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_40442_row0_col5 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_40442_row0_col6, #T_40442_row2_col5, #T_40442_row3_col0 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_40442_row0_col7, #T_40442_row7_col9 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_40442_row0_col8 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_40442_row0_col9, #T_40442_row3_col1, #T_40442_row4_col2 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_40442_row0_col10 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_40442_row1_col2 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_40442_row1_col3, #T_40442_row4_col3 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_40442_row1_col4, #T_40442_row6_col0, #T_40442_row6_col1, #T_40442_row6_col2, #T_40442_row6_col3, #T_40442_row6_col5, #T_40442_row6_col7, #T_40442_row6_col8, #T_40442_row6_col9, #T_40442_row6_col10, #T_40442_row7_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_40442_row1_col5 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_40442_row1_col6 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_40442_row1_col7 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_40442_row1_col8 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_40442_row1_col9, #T_40442_row5_col1 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_40442_row1_col10 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_40442_row2_col0 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_40442_row2_col1 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_40442_row2_col3, #T_40442_row8_col3 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_40442_row2_col4 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_40442_row2_col6, #T_40442_row3_col4 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_40442_row2_col7 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_40442_row2_col8 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_40442_row2_col9, #T_40442_row3_col9 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_40442_row2_col10 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_40442_row3_col2, #T_40442_row9_col10 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_40442_row3_col5 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_40442_row3_col6, #T_40442_row8_col0 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_40442_row3_col7, #T_40442_row7_col2 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_40442_row3_col8 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_40442_row3_col10 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_40442_row4_col0, #T_40442_row5_col3, #T_40442_row5_col6, #T_40442_row10_col5 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_40442_row4_col1 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_40442_row4_col5 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_40442_row4_col6 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_40442_row4_col7 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_40442_row4_col8 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_40442_row4_col9 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_40442_row5_col0 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_40442_row5_col2 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_40442_row5_col4 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_40442_row5_col7 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_40442_row5_col8, #T_40442_row10_col9 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_40442_row5_col9 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_40442_row5_col10, #T_40442_row9_col5 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_40442_row6_col4 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_40442_row7_col0 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_40442_row7_col1 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_40442_row7_col3 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_40442_row7_col4, #T_40442_row10_col3 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_40442_row7_col5 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_40442_row7_col8 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_40442_row7_col10 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_40442_row8_col1 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_40442_row8_col2 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_40442_row8_col4 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_40442_row8_col5 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_40442_row8_col6, #T_40442_row10_col6 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_40442_row8_col7 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_40442_row8_col9 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_40442_row8_col10, #T_40442_row10_col8 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_40442_row9_col0 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_40442_row9_col1 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_40442_row9_col2 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_40442_row9_col3 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_40442_row9_col4 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_40442_row9_col6 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_40442_row9_col7 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_40442_row9_col8 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_40442_row10_col0 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_40442_row10_col1 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_40442_row10_col2 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_40442_row10_col4 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_40442_row10_col7 {
#   background-color: #f7b599;
#   color: #000000;
# }
# </style>
# <table id="T_40442">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_40442_level0_col0" class="col_heading level0 col0" >age</th>
#       <th id="T_40442_level0_col1" class="col_heading level0 col1" >sex</th>
#       <th id="T_40442_level0_col2" class="col_heading level0 col2" >bmi</th>
#       <th id="T_40442_level0_col3" class="col_heading level0 col3" >bp</th>
#       <th id="T_40442_level0_col4" class="col_heading level0 col4" >s1</th>
#       <th id="T_40442_level0_col5" class="col_heading level0 col5" >s2</th>
#       <th id="T_40442_level0_col6" class="col_heading level0 col6" >s3</th>
#       <th id="T_40442_level0_col7" class="col_heading level0 col7" >s4</th>
#       <th id="T_40442_level0_col8" class="col_heading level0 col8" >s5</th>
#       <th id="T_40442_level0_col9" class="col_heading level0 col9" >s6</th>
#       <th id="T_40442_level0_col10" class="col_heading level0 col10" >target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_40442_level0_row0" class="row_heading level0 row0" >age</th>
#       <td id="T_40442_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_40442_row0_col1" class="data row0 col1" >0.173737</td>
#       <td id="T_40442_row0_col2" class="data row0 col2" >0.185085</td>
#       <td id="T_40442_row0_col3" class="data row0 col3" >0.335427</td>
#       <td id="T_40442_row0_col4" class="data row0 col4" >0.260061</td>
#       <td id="T_40442_row0_col5" class="data row0 col5" >0.219243</td>
#       <td id="T_40442_row0_col6" class="data row0 col6" >-0.075181</td>
#       <td id="T_40442_row0_col7" class="data row0 col7" >0.203841</td>
#       <td

# %%
X = diabetes_frame.iloc[:,8:9].values
y = diabetes_frame.iloc[:,10:11].values

pipeline = make_pipeline(PolynomialFeatures(4), LinearRegression())
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
pipeline.fit(np.array(X_train), y_train)
y_pred=pipeline.predict(X_test)

# %%
df = pd.DataFrame({'x': X_test[:,0], 'y': y_pred[:,0]})
df.sort_values(by='x',inplace = True)
points = pd.DataFrame(df).to_numpy()

plt.plot(points[:, 0], points[:, 1],color="blue", linewidth=3)
plt.xlabel('Package')
plt.ylabel('Price')
plt.scatter(X,y, color="black")
plt.show()

# %%
accuracy_score = pipeline.score(X_train,y_train)
print('Model Accuracy: ', accuracy_score)
# Out:
# Model Accuracy:  0.37592400086615063
